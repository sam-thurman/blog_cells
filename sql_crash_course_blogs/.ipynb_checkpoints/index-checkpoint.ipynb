# %%
import numpy as np
import random
import pandas as pd
from pandasql import sqldf

# %%
names = ['Liam',
         'Olivia',
         'Noah',
         'Emma',
         'Oliver',
         'Ava',
         'William',
         'Sophia',
         'Elijah',
         'Isabella',
         'James',
         'Charlotte',
         'Benjamin',
         'Amelia',
         'Lucas',
         'Mia',
         'Mason',
         'Harper',
         'Ethan',
         'Evelyn']
cols = ['name']
for i in range(1,11):
    cols.append(f'test_{i}_score')

# %%
data = []
for i in range(20):
    row = [names[i]]
    for j in range(10):
        row.append(random.randint(60, 100))
    data.append(row)
    
scores = pd.DataFrame(data, columns=cols)

# %% [markdown]
# ### WHERE

# %% [markdown]
# syntax:\
# SELECT column1, column2, ...\
# FROM table_name\
# WHERE condition1;

# %%
sqldf('''
SELECT name, test_1_score FROM scores WHERE test_1_score < 77;
''')
# Out:
#         name  test_1_score
# 0       Liam            72
# 1       Noah            66
# 2       Emma            62
# 3     Sophia            68
# 4  Charlotte            60
# 5     Amelia            65
# 6      Lucas            74
# 7      Ethan            60

# %%
sqldf('''
SELECT name, test_10_score FROM scores WHERE test_10_score > 90;
''')
# Out:
#      name  test_10_score
# 0  Sophia            100
# 1   Lucas             91

# %% [markdown]
# ### between 2 values

# %%
# Doesn't work, we can see we have some incorrect scores
sqldf('''
SELECT name, test_10_score FROM scores WHERE 80 < test_10_score < 90;
''')
# Out:
#          name  test_10_score
# 0        Liam             79
# 1      Olivia             86
# 2        Noah             72
# 3        Emma             75
# 4      Oliver             78
# 5         Ava             66
# 6     William             61
# 7      Sophia            100
# 8      Elijah             74
# 9    Isabella             79
# 10      James             67
# 11  Charlotte             68
# 12   Benjamin             90
# 13     Amelia             82
# 14      Lucas             91
# 15        Mia             80
# 16      Mason             85
# 17     Harper             83
# 18      Ethan             82
# 19     Evelyn             70

# %%
# Gives us the filtering we want
sqldf('''
SELECT name, test_10_score FROM scores WHERE test_10_score BETWEEN 80 AND 90;
''')
# Out:
#        name  test_10_score
# 0    Olivia             86
# 1  Benjamin             90
# 2    Amelia             82
# 3       Mia             80
# 4     Mason             85
# 5    Harper             83
# 6     Ethan             82

# %% [markdown]
# # AND, OR

# %% [markdown]
# syntax: \
# SELECT column1, column2, ... \
# FROM table_name \
# WHERE condition1 AND/OR condition2 AND/OR condition3 ...;

# %%
sqldf('''
SELECT name FROM scores WHERE test_1_score < 75 AND test_10_score > 85;
''')
# Out:
#      name
# 0  Sophia
# 1   Lucas

# %%
sqldf('''
SELECT name FROM scores WHERE test_1_score > 85 OR test_2_score > 85;
''')
# Out:
#         name
# 0       Liam
# 1     Olivia
# 2       Emma
# 3     Oliver
# 4        Ava
# 5     Elijah
# 6   Isabella
# 7      James
# 8     Amelia
# 9        Mia
# 10    Harper
# 11    Evelyn

# %%
sqldf('''
SELECT name FROM scores WHERE test_1_score < 75 OR test_2_score < 75 AND test_10_score < 75;
''')
# Out:
#         name
# 0       Liam
# 1       Noah
# 2       Emma
# 3    William
# 4     Sophia
# 5  Charlotte
# 6     Amelia
# 7      Lucas
# 8      Ethan
# 9     Evelyn

# %% [markdown]
# # ORDER BY

# %%
scores['test_avg'] = scores.apply(lambda row: np.mean(row[1:]), axis=1)

# %%
sqldf('''
SELECT name, test_avg FROM scores ORDER BY test_avg;
''')
# Out:
#          name  test_avg
# 0       Ethan      73.3
# 1   Charlotte      74.9
# 2        Liam      75.2
# 3       Lucas      76.1
# 4     William      76.2
# 5        Noah      76.3
# 6    Benjamin      77.4
# 7      Evelyn      78.8
# 8      Olivia      79.0
# 9       James      79.1
# 10     Elijah      79.3
# 11        Ava      79.5
# 12       Emma      79.6
# 13        Mia      80.4
# 14      Mason      80.9
# 15     Sophia      81.6
# 16     Oliver      82.1
# 17     Amelia      82.2
# 18     Harper      84.3
# 19   Isabella      86.8

# %%
sqldf('''
SELECT name, test_avg FROM scores ORDER BY test_avg DESC;
''')
# Out:
#          name  test_avg
# 0    Isabella      86.8
# 1      Harper      84.3
# 2      Amelia      82.2
# 3      Oliver      82.1
# 4      Sophia      81.6
# 5       Mason      80.9
# 6         Mia      80.4
# 7        Emma      79.6
# 8         Ava      79.5
# 9      Elijah      79.3
# 10      James      79.1
# 11     Olivia      79.0
# 12     Evelyn      78.8
# 13   Benjamin      77.4
# 14       Noah      76.3
# 15    William      76.2
# 16      Lucas      76.1
# 17       Liam      75.2
# 18  Charlotte      74.9
# 19      Ethan      73.3

# %%
sqldf('''
SELECT name, test_10_score, test_avg FROM scores ORDER BY test_avg, test_10_score;
''')
# Out:
#          name  test_10_score  test_avg
# 0       Ethan             82      73.3
# 1   Charlotte             68      74.9
# 2        Liam             79      75.2
# 3       Lucas             91      76.1
# 4     William             61      76.2
# 5        Noah             72      76.3
# 6    Benjamin             90      77.4
# 7      Evelyn             70      78.8
# 8      Olivia             86      79.0
# 9       James             67      79.1
# 10     Elijah             74      79.3
# 11        Ava             66      79.5
# 12       Emma             75      79.6
# 13        Mia             80      80.4
# 14      Mason             85      80.9
# 15     Sophia            100      81.6
# 16     Oliver             78      82.1
# 17     Amelia             82      82.2
# 18     Harper             83      84.3
# 19   Isabella             79      86.8

# %% [markdown]
# # GROUP BY

# %%
conditions = [
    (scores['test_avg']>=93),
    (scores['test_avg']>=90),
    (scores['test_avg']>=87),
    (scores['test_avg']>=83),
    (scores['test_avg']>=80),
    (scores['test_avg']>=77),
    (scores['test_avg']>=73),
    (scores['test_avg']>=70),
    (scores['test_avg']>=67),
    (scores['test_avg']>=60),
    (scores['test_avg']<60)]
choices = ['A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D', 'F']
scores['grade'] = np.select(conditions, choices, default='Z')
scores
# Out:
#          name  test_1_score  test_2_score  test_3_score  test_4_score  \
# 0        Liam            72            91            87            96
# 1      Olivia            99            79            61            74
# 2        Noah            66            75            81            79
# 3        Emma            62            89            79            77
# 4      Oliver            95            84            83            63
# 5         Ava            84            95            83            89
# 6     William            82            67            60            99
# 7      Sophia            68            82            97            95
# 8      Elijah            92            75            71            80
# 9    Isabella            95            86            97            95
# 10      James            82            99            79            67
# 11  Charlotte            60            75            62           100
# 12   Benjamin            78            69            63            62
# 13     Amelia            65            95            61            94
# 14      Lucas            74            83            75            66
# 15        Mia            96            77            70            79
# 16      Mason            78            85            75            63
# 17     Harper            95            89            64            95
# 18      Ethan            60            82            68            64
# 19     Evelyn            93            62            87           100
#
#     test_5_score  test_6_score  test_7_score  test_8_score  test_9_score  \
# 0             71            66            63            61            66
# 1             67            74            86            78            86
# 2             70            79            82            60            99
# 3             70           100            93            65            86
# 4             82            67            99            95            75
# 5             73            76            89            71            69
# 6             89            67            63            76            98
# 7             69            63            95            79            68
# 8             86            67            76            96            76
# 9             98            61            94            96            67
# 10            78            81            61            82            95
# 11            70            75            77            81            81
# 12            88            61            97            93            73
# 13            99            81            75            98            72
# 14            61            65            89            79            78
# 15            77            63            67            95           100
# 16            84            76            80            84            99
# 17            82            87            67            99            82
# 18            64            74            76            76            87
# 19            83            85            65            76            67
#
#     test_10_score  test_avg grade
# 0              79      75.2     C
# 1              86      79.0    C+
# 2              72      76.3     C
# 3              75      79.6    C+
# 4              78      82.1    B-
# 5              66      79.5    C+
# 6              61      76.2     C
# 7             100      81.6    B-
# 8              74      79.3    C+
# 9              79      86.8     B
# 10             67      79.1    C+
# 11             68      74.9     C
# 12             90      77.4    C+
# 13             82      82.2    B-
# 14             91      76.1     C
# 15             80      80.4    B-
# 16             85      80.9    B-
# 17             83      84.3     B
# 18             82      73.3     C
# 19             70      78.8    C+

# %%
sqldf('''
SELECT grade, COUNT(name) FROM scores GROUP BY grade;
''')
# Out:
#   grade  COUNT(name)
# 0     B            2
# 1    B-            5
# 2     C            6
# 3    C+            7

# %%
sqldf('''
SELECT grade, AVG(test_avg) FROM scores GROUP BY grade;
''')
# Out:
#   grade  AVG(test_avg)
# 0     B      85.550000
# 1    B-      81.440000
# 2     C      75.333333
# 3    C+      78.957143

# %%
sqldf('''
SELECT AVG(test_1_score) AS test_1_avg FROM scores;
''')
# Out:
#    test_1_avg
# 0        79.8
