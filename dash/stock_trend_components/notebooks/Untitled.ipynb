# %%
import yfinance
import pandas as pd
import plotly.express as px
import plotly as pl

# %%
cos = ['GOOG', 'AAPL', 'AMZN', 'FB', 'NFLX', 'MSFT', 'SPOT', 'TSLA']

closes = []

for co in cos:
    series = yfinance.Ticker(co).history(period='1y').rename({'Close':co}, axis=1)[co]
    closes.append(series)

# %%
master = pd.concat(closes, axis=1)
master
# Out:
#                    GOOG        AAPL         AMZN          FB        NFLX  \
# Date
# 2019-12-02  1289.920044   64.942841  1781.599976  199.699997  309.989990
# 2019-12-03  1295.280029   63.784916  1769.959961  198.820007  306.160004
# 2019-12-04  1320.540039   64.347893  1760.689941  198.710007  304.320007
# 2019-12-05  1328.130005   65.291946  1740.479980  199.360001  302.859985
# 2019-12-06  1340.619995   66.553131  1751.599976  201.050003  307.350006
# ...                 ...         ...          ...         ...         ...
# 2020-11-23  1734.859985  113.849998  3098.389893  268.429993  476.619995
# 2020-11-24  1768.880005  115.169998  3118.060059  276.920013  482.880005
# 2020-11-25  1771.430054  116.029999  3185.070068  275.589996  485.000000
# 2020-11-27  1793.189941  116.589996  3195.340088  277.809998  491.359985
# 2020-11-30  1760.739990  119.050003  3168.040039  276.970001  490.700012
#
#                   MSFT        SPOT        TSLA
# Date
# 2019-12-02  147.982330  142.529999   66.973999
# 2019-12-03  147.744843  143.979996   67.239998
# 2019-12-04  148.279175  144.949997   66.606003
# 2019-12-05  148.358353  146.580002   66.073997
# 2019-12-06  150.159271  148.089996   67.178001
# ...                ...         ...         ...
# 2020-11-23  210.110001  268.859985  521.849976
# 2020-11-24  213.860001  270.140015  555.380005
# 2020-11-25  213.869995  270.089996  574.000000
# 2020-11-27  215.229996  277.619995  585.760010
# 2020-11-30  214.070007  291.369995  567.599976
#
# [252 rows x 8 columns]

# %%
px.line(master.GOOG)
