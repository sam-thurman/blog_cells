# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = r'f(x) = \frac{\exp(-x^2/2)}{\sqrt{2*\pi}}'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
# Out:
# Text(0.4, 0.4, '$f(x) = \\frac{\\exp(-x^2/2)}{\\sqrt{2*\\pi}}$')

# %%
a = r'P(A|B) = \frac{P(B|A)P(A)}{P(B)}'
ax = plt.axes([0,0,0,1.5]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
plt.savefig('figs/bayes_theorem_h.png')

# %%
a = r'P(S|B) = \frac{P(B|S)P(S)}{P(B)}'
ax = plt.axes([0,0,0,1.5]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
plt.savefig('figs/fishtank_1.png')

# %%
P( beta fish ) = 45/245 -- 45 betas out of a total fish pop of 245
P( small tank ) = 10/245 -- 10 fish in the small tank divided by 245 fish in both tanks
P( beta fish | small tank ) = 1 -- all fish in the small tank are betas
# Out:
#   File "<ipython-input-10-1de25905127c>", line 1
#     P( beta fish ) = 45/245 -- 45 betas out of a total fish pop of 245
#                ^
# SyntaxError: invalid syntax

# %%
a = r'P(S|B) = \frac{(1)(\frac{10}{245})}{(\frac{45}{245})}'
ax = plt.axes([0,0,0,1.5]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
plt.savefig('figs/fishtank_2.png')

# %%
a = r'P(S|B) = \frac{10}{45} = 0.22222...'
ax = plt.axes([0,0,0,1.5]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
plt.savefig('figs/fishtank_3.png')

# %%
a = r'P(S|O) = \frac{P(O|S)P(S)}{P(O)}'
ax = plt.axes([0,0,0,1.5]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
plt.savefig('figs/nlp_1.png')

# %%
P(offer) = P(spam)•P(Offer | Spam)+P(~Spam)•P(Offer | ~Spam)
# Out:
#   File "<ipython-input-14-c31b1975a31e>", line 1
#     P(offer) = P(spam)•P(Offer | Spam)+P(~Spam)•P(Offer | ~Spam)
#                        ^
# SyntaxError: invalid character in identifier

# %%
a = r'P(O) = P(S)•P(O|S) + P($~$S)•P(O|$~$S)'
ax = plt.axes([0,0,0,1.5]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
plt.savefig('figs/nlp_2.png')

# %%
P(offer) = .15 • .73 + .85 • .1
# Out:
#   File "<ipython-input-16-f1ff67cfdf7c>", line 1
#     P(offer) = .15 • .73 + .85 • .1
#                    ^
# SyntaxError: invalid character in identifier

# %%
a = r'P(O) = (.15)•(.73) + (.85)•(.1) = .1945'
ax = plt.axes([0,0,0,1.5]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
plt.savefig('figs/nlp_3.png')

# %%
a = r'P(S|O) = \frac{(.73)(.15)}{(.1945)} = 0.56298'
ax = plt.axes([0,0,0,1.5]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
plt.savefig('figs/nlp_4.png')
