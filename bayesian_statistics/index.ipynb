# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
! pip install pylatex
# Out:
# Collecting pylatex
#   Downloading PyLaTeX-1.4.1.tar.gz (84 kB)
#      |████████████████████████████████| 84 kB 673 kB/s eta 0:00:01
# Collecting ordered-set
#   Downloading ordered-set-4.0.2.tar.gz (10 kB)
# Building wheels for collected packages: pylatex, ordered-set
#   Building wheel for pylatex (setup.py) ... done
#   Created wheel for pylatex: filename=PyLaTeX-1.4.1-py3-none-any.whl size=42812 sha256=56fac0cc476371e21ece0951f8d824db89223059ee7a53eeaae728b0e8fe3f86
#   Stored in directory: /Users/sam/Library/Caches/pip/wheels/f8/12/ad/5bd567f36e0db696dbbd430a4c6431894f53e22ff7d7ff8d98
#   Building wheel for ordered-set (setup.py) ... done
#   Created wheel for ordered-set: filename=ordered_set-4.0.2-py2.py3-none-any.whl size=8209 sha256=8a9bbcb6ce69df7a5f338b79561979de1a6c587e5a3e72f26f9264537776fcb7
#   Stored in directory: /Users/sam/Library/Caches/pip/wheels/89/42/11/6ac0b34daaf88414eb260022bab0b52fa8b2a4fb3c2a76524d
# Successfully built pylatex ordered-set
# Installing collected packages: ordered-set, pylatex
# Successfully installed ordered-set-4.0.2 pylatex-1.4.1

# %%
a = r'f(x) = \frac{\exp(-x^2/2)}{\sqrt{2*\pi}}'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
# Out:
# Text(0.4, 0.4, '$f(x) = \\frac{\\exp(-x^2/2)}{\\sqrt{2*\\pi}}$')

# %%
a = r'P(S|B) = \frac{P(B|S)P(S)}{P(B)}'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
# Out:
# Text(0.4, 0.4, '$P(S|B) = \\frac{P(B|S)P(S)}{P(B)}$')

# %%
P( beta fish ) = 45/245 -- 45 betas out of a total fish pop of 245
P( small tank ) = 10/245 -- 10 fish in the small tank divided by 245 fish in both tanks
P( beta fish | small tank ) = 1 -- all fish in the small tank are betas

# %%
a = r'P(S|B) = \frac{(1)(\frac{10}{245})}{(\frac{45}{245})}'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
# Out:
# Text(0.4, 0.4, '$P(S|B) = \\frac{(1)(\\frac{10}{245})}{(\\frac{45}{245})}$')

# %%
a = r'P(S|B) = \frac{10}{45} = 0.22222...'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
# Out:
# Text(0.4, 0.4, '$P(S|B) = \\frac{10}{45} = 0.22222...$')

# %%
a = r'P(S|O) = \frac{P(O|S)P(S)}{P(O)}'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
# Out:
# Text(0.4, 0.4, '$P(S|O) = \\frac{P(O|S)P(S)}{P(O)}$')

# %%
P(offer) = P(spam)•P(Offer | Spam)+P(~Spam)•P(Offer | ~Spam)

# %%
a = r'P(O) = P(S)•P(O|S) + P($~$S)•P(O|$~$S)'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
# Out:
# Text(0.4, 0.4, '$P(O) = P(S)•P(O|S) + P($~$S)•P(O|$~$S)$')

# %%
P(offer) = .15 • .73 + .85 • .1

# %%
a = r'P(O) = (.15)•(.73) + (.85)•(.1) = .1945'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
# Out:
# Text(0.4, 0.4, '$P(O) = (.15)•(.73) + (.85)•(.1) = .1945$')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-967069828d63> in <module>
# ----> 1 (.73)(.15)
#
# TypeError: 'float' object is not callable

# %%
a = r'P(S|O) = \frac{(.73)(.15)}{(.1945)} = 0.56298'
ax = plt.axes([0,0,0.3,0.3]) #left,bottom,width,height
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.text(0.4,0.4,'$%s$' %a,size=50,color="black")
# Out:
# Text(0.4, 0.4, '$P(S|O) = \\frac{(.73)(.15)}{(.1945)} = 0.56298$')
